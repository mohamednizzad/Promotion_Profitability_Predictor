# %%
# !pip install seaborn
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# 1. Generate the Confusion Matrix array
cm = confusion_matrix(y_test, y_hat_tuned)

# 2. Visualize the matrix as a heatmap
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Predicted Failure (0)', 'Predicted Success (1)'],
            yticklabels=['Actual Failure (0)', 'Actual Success (1)'])

plt.title('Tuned Model Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# Extracting the key business values
TN, FP, FN, TP = cm.ravel()
print(f"\nKey Business Metrics:")
print(f"False Positives (FP/Financial Loss): {FP}")
print(f"True Positives (TP/Correct Successes): {TP}")
print(f"Precision Check: {TP / (TP + FP):.4f}")
# Out:
# Key Business Metrics:
# False Positives (FP/Financial Loss): 5514
# True Positives (TP/Correct Successes): 23140
# Precision Check: 0.8076

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 1. Extract Coefficients and Feature Names
# Coefficients are usually returned as a 2D array, so we take the first row [0]
coefficients = model.coef_[0]
feature_names = X_train.columns

# 2. Create a DataFrame for easy sorting and plotting
feature_importance = pd.DataFrame({
    'Feature': feature_names,
    'Coefficient': coefficients
})

# Sort by coefficient magnitude (for a clean visual)
feature_importance = feature_importance.sort_values(by='Coefficient', ascending=False)

# 3. Plot the Feature Importance
plt.figure(figsize=(10, 6))
sns.barplot(x='Coefficient', y='Feature', data=feature_importance, palette='viridis')

plt.title('Logistic Regression Feature Importance (Impact on Success)')
plt.xlabel('Coefficient Value (Impact on Success Probability)')
plt.ylabel('Promotion/Store Feature')
plt.axvline(0, color='red', linestyle='--') # Add a line at zero for clear separation
plt.show()

print("\n--- Top Business Insight from Coefficients ---")
print(f"Most Powerful Success Driver (Positive Impact): {feature_importance.iloc[0]['Feature']}")
print(f"Largest Risk Factor (Negative Impact): {feature_importance.iloc[-1]['Feature']}")
# Out:
# C:\Users\Mohamed Nizzad\AppData\Local\Temp\ipykernel_17052\2104426885.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Coefficient', y='Feature', data=feature_importance, palette='viridis')
# --- Top Business Insight from Coefficients ---
# Most Powerful Success Driver (Positive Impact): Is_Promoted
# Largest Risk Factor (Negative Impact): Promo_Type_None
